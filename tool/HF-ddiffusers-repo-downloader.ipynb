# %% [markdown]
# <a href="https://colab.research.google.com/github/steinhaug/stable-diffusion/blob/main/tool/HF-ddiffusers-repo-downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata
HF_TOKEN = userdata.get('HF_TOKEN')

# !huggingface-cli login --token {HF_TOKEN}
from huggingface_hub import snapshot_download
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
import os
SAVE_PATH = '/content/drive/MyDrive/models/LLaVA'
REPO_ID = '4bit/llava-v1.5-13b-5GB'
os.makedirs(f"{SAVE_PATH}/{REPO_ID}", exist_ok=True)
path = snapshot_download(repo_id=REPO_ID, repo_type="model", revision="main", local_dir=f"{SAVE_PATH}/{REPO_ID}", local_dir_use_symlinks=False)
# Out:
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/82.6k [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/154 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# pytorch_model-00002-of-00004.bin:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# pytorch_model-00003-of-00004.bin:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# pytorch_model-00001-of-00004.bin:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# pytorch_model-00004-of-00004.bin:   0%|          | 0.00/607M [00:00<?, ?B/s]

# %%
import os
SAVE_PATH = '/content/drive/MyDrive/models/LLaVA'
REPO_ID = '4bit/llava-v1.5-13b-3GB'
os.makedirs(f"{SAVE_PATH}/{REPO_ID}", exist_ok=True)
path = snapshot_download(repo_id=REPO_ID, repo_type="model", revision="main", local_dir=f"{SAVE_PATH}/{REPO_ID}", local_dir_use_symlinks=False)
# Out:
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/154 [00:00<?, ?B/s]
# pytorch_model-00006-of-00009.bin:   0%|          | 0.00/2.98G [00:00<?, ?B/s]
# pytorch_model-00004-of-00009.bin:   0%|          | 0.00/2.96G [00:00<?, ?B/s]
# pytorch_model-00005-of-00009.bin:   0%|          | 0.00/2.89G [00:00<?, ?B/s]
# pytorch_model-00003-of-00009.bin:   0%|          | 0.00/2.89G [00:00<?, ?B/s]
# pytorch_model-00002-of-00009.bin:   0%|          | 0.00/2.93G [00:00<?, ?B/s]
# pytorch_model-00001-of-00009.bin:   0%|          | 0.00/2.97G [00:00<?, ?B/s]
# pytorch_model-00007-of-00009.bin:   0%|          | 0.00/2.87G [00:00<?, ?B/s]
# pytorch_model-00008-of-00009.bin:   0%|          | 0.00/2.89G [00:00<?, ?B/s]
# pytorch_model-00009-of-00009.bin:   0%|          | 0.00/2.72G [00:00<?, ?B/s]
# ...

# %%
import os
SAVE_PATH = '/content/drive/MyDrive/models/LLaVA'
REPO_ID = '4bit/ShareGPT4V-7B-5GB'
os.makedirs(f"{SAVE_PATH}/{REPO_ID}", exist_ok=True)
path = snapshot_download(repo_id=REPO_ID, repo_type="model", revision="main", local_dir=f"{SAVE_PATH}/{REPO_ID}", local_dir_use_symlinks=False)
# Out:
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/76.0k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# pytorch_model-00003-of-00003.bin:   0%|          | 0.00/4.24G [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# pytorch_model-00001-of-00003.bin:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# pytorch_model-00002-of-00003.bin:   0%|          | 0.00/4.95G [00:00<?, ?B/s]

# %%
import os
SAVE_PATH = '/content/drive/MyDrive/models/LLaVA'
REPO_ID = 'liuhaotian/llava-v1.5-7b'
os.makedirs(f"{SAVE_PATH}/{REPO_ID}", exist_ok=True)
path = snapshot_download(repo_id=REPO_ID, repo_type="model", revision="main", local_dir=f"{SAVE_PATH}/{REPO_ID}", local_dir_use_symlinks=False)
# Out:
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/27.1k [00:00<?, ?B/s]
# mm_projector.bin:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.54G [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]

# %%
LLaVA_13b_8bit_colab.ipynb
LLaVA_13b_4bit_caption_colab.ipynb

LLaVA_13b_4bit_colab.ipynb
Disk: 57,4 - GPU: 7,6 - GO!

LLaVA_7b_colab 7B (16bit) (Pro High-RAM 😐 22GB RAM 14GB VRAM)
